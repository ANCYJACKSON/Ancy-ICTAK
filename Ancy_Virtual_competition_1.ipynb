# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import  seaborn as sns

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

daf = pd.DataFrame(data , index=labels)
print(daf)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
#   Displaying a summary of the basic information about this DataFrame and its data
print("Summary of the basic information about this DataFrame and its data:")
print(daf.info())
# Out:
# Summary of the basic information about this DataFrame and its data:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes
# None

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
#    Return first 3 rows from the dataframe
daf1 = daf.head(3)
#    display the dataframe
daf1
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
#     Display 'animal' and 'age' columns from the DataFrame
daf[['animal', 'age']]
daf
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
#     Displaying data in rows [3,4,8] and in columns ['animal','age']
daf.loc[daf.index[[3, 4, 8]], ['animal', 'age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
#   displaying only the rows where the number of visits is greater than 3.
daf[daf['visits'] > 3]
#  No rows selected as there are no rows with no.of visits > 3
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
#     Display the rows where the age is missing i.e. it is NaN.
daf[daf['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
#     Displaying the rows where the animal is a cat and the age is less than 3
daf[(daf['animal'] == 'cat') & (daf['age'] < 3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
#   Display the rows where the age is between 2 and 4 (inclusive)
daf[daf['age'].between(2, 4)]
#daf = daf[(daf['age'] >= 2) & (daf['age'] <= 4)]
#daf
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
#     Change the age in row 'f' to 1.5 and then display the dataset
daf.loc['f', 'age'] = 1.5
daf
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
#     Calculating the sum of all visits in dataframe and displaying it
print('Sum of all visits : ', daf['visits'].sum())
# Out:
# Sum of all visits :  19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
#     calculate the mean age for each different animal in dataframe and display it.
daf.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
#     Append a new row 'k' to the dataframe
daf.loc['k'] = ['snake', 3.5,  2, 'yes']
daf
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# k  snake  3.5       2      yes

# %%
#     Delete the recently appended row to return the original DataFrame
daf = daf.drop('k')
daf
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
#   count the number of each type of animal in df
daf['animal'].value_counts()
# Out:
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
#   Sort by the values in the 'age' in decending order,
#   then by the values in the 'visits' column in ascending order
daf.sort_values(by=['age', 'visits'], ascending=[False, True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
#   Replace the value 'yes' with 'True' and 'no' with 'False' in the 'priority' column
daf['priority'] = daf['priority'].map({'yes': True, 'no': False})
daf
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  1.5       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
#     Replace all the 'snake' entries to 'python' in the 'animal' column
daf['animal'] = daf['animal'].replace('snake', 'python')
daf
# Out:
#    animal  age  visits  priority
# a     cat  2.5       1      True
# b     cat  3.0       3      True
# c  python  0.5       2     False
# d     dog  NaN       3      True
# e     dog  5.0       2     False
# f     cat  1.5       3     False
# g  python  4.5       1     False
# h     cat  NaN       1      True
# i     dog  7.0       2     False
# j     dog  3.0       1     False

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
#   Load the ny-flights dataset to Python
df_flight = pd.read_csv('/content/ny-flights.csv')

# %%
df_flight.head()
# Out:
#                fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0  2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1  2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2  2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3  2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4  2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
#
#   dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 0  LAX     914.0       14.0    1238.0       13.0        0.0
# 1  LAX    1157.0       -3.0    1523.0       13.0        0.0
# 2  LAX    1902.0        2.0    2224.0        9.0        0.0
# 3  PBI     722.0       -8.0    1014.0      -26.0        0.0
# 4  LAX    1347.0        2.0    1706.0        1.0        0.0
#
#                    arr                  dep
# 0  2014-01-01 12:38:00  2014-01-01 09:14:00
# 1  2014-01-01 15:23:00  2014-01-01 11:57:00
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
df_flight.air_id = df_flight['airline_id'].value_counts().idxmax()
print('Airline ID that repeats the most : ', df_flight.air_id)

#   another way
#print('Airline ID that repeats the most : ', df_flight['airline_id'].mode()[0])
# Out:
# Airline ID that repeats the most :  20409

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
plt.plot(df_flight['dep_delay'], df_flight['arr_delay'])
plt.title('Plot between Departure Delay and Arrival Delay')      # giving title for the plot
plt.xlabel('dep delay')               # labelling X axis
plt.ylabel('arr delay')               # labelling Y axis
# Out:
# Text(0, 0.5, 'arr delay')

# %%
df_flight.groupby('dep_delay')['arr_delay'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='dep_delay'>

# %%
sns.lineplot(data=df_flight, x='dep_delay', y='arr_delay')
plt.title('Plot between Departure Delay and Arrival Delay')      # giving title for the plot
plt.xlabel('dep_delay')
plt.ylabel('arr_delay')
# Out:
# Text(0, 0.5, 'arr_delay')

# %%
plt.plot(df_flight['dep_delay'], df_flight['arr_delay'])
plt.title('Plot between Departure Delay and Arrival Delay')      # giving title for the plot
plt.show()

# %%
sns.boxplot(data=df_flight, x='dep_delay', y='arr_delay', hue='airline_id')
# Out:
# <Axes: xlabel='dep_delay', ylabel='arr_delay'>

# %%
df_flight.plot(kind = 'scatter', x='dep_delay', y='arr_delay')
# Out:
# <Axes: xlabel='dep_delay', ylabel='arr_delay'>
